# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv('social.csv')
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
# Picking features 
features=df.iloc[:,:-1].values # It will df into numpy array
features
# Out:
# array([[15624510, 'Male', 19, 19000],
#        [15810944, 'Male', 35, 20000],
#        [15668575, 'Female', 26, 43000],
#        ...,
#        [15654296, 'Female', 50, 20000],
#        [15755018, 'Male', 36, 33000],
#        [15594041, 'Female', 49, 36000]], dtype=object)

# %%
label=df.iloc[:,-1].values
#label

# %%
actual_features=features[:,2:4]
actual_features.shape
# Out:
# (400, 2)

# %%
# feature scalling 
from sklearn.preprocessing import StandardScaler
f_sc=StandardScaler()

# %%
# Now training and testing data separation
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(actual_features,label,test_size=0.2)

# %%
# Applying feature scalling 
final_train=f_sc.fit_transform(train_x) # Always max of training data

# %%
final_train
# Out:
# array([[ 0.71565929, -1.3990656 ],
#        [ 1.57409275, -1.28138117],
#        [-0.42891866, -1.22253896],
#        [ 0.23875181, -0.66353792],
#        [-0.42891866, -0.78122235],
#        [-0.14277418, -0.45759016],
#        [-1.00120764, -1.54617114],
#        [ 1.00180377,  0.13083199],
#        [ 0.14337031, -0.25164241],
#        [ 0.90642228, -1.3696445 ],
#        [-1.00120764,  0.60156971],
#        [ 1.38332976, -1.42848671],
#        [-0.23815567,  0.07198977],
#        [-0.61968166, -1.60501336],
#        [-0.33353717,  1.24883407],
#        [-0.71506315,  1.92551955],
#        [ 1.00180377,  1.45478183],
#        [-1.09658913,  0.30735863],
#        [ 1.28794826,  1.89609844],
#        [-0.81044465,  0.30735863],
#        [-0.71506315,  1.3665185 ],
#        [ 0.3341333 , -0.51643238],
#        [-1.47811512, -0.42816906],
#        [-0.52430016,  1.92551955],
#        [-1.09658913, -1.57559225],
#        [-1.28735213, -1.10485453],
#        [ 2.05100023,  0.54272749],
# ...

# %%
#testing data
final_test=f_sc.transform(test_x)  # only testing data

# %%
# calling random forest classifier
clf=RandomForestClassifier(n_estimators=30,criterion='entropy')
